# %% [markdown]
# **1. Mount Google Drive to Colab Notebook**
#
# This step is necessary to access files stored in your Google Drive directly from the Colab notebook.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **2. Load and Process the Text File**
#
# Here we are opening a text file that contains the data we will use to fine-tune the GPT-2 model. The file is read line by line, and each line is stripped of any leading or trailing white space. You should install your txt file to your google drive as well.

# %%
with open('/content/drive/My Drive/statementlarsscv3.txt', 'r') as f:
    lines=f.readlines()
lines = [line.strip() for line in lines]
print(len(lines))
# Out:
# 2410

# %% [markdown]
# **3. Install Necessary Libraries**
#
# We need several libraries for this project, including Hugging Face's transformers and datasets, the accelerate library for mixed-precision training, and others. You also need to open a huggingface account and get a huggingface token to access your hub.

# %%
# !pip install transformers[torch]
# !pip install accelerate -U
#!pip install transformers
# !pip install datasets
# !pip install --upgrade huggingface_hub
# !huggingface-cli login
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.65.0)
# Requirement already satisfied: torch!=1.12.0,>=1.9 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.0.1+cu118)
# Requirement already satisfied: accelerate>=0.20.2 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.21.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.2->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers[torch]) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers[torch]) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers[torch]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers[torch]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers[torch]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.12.0,>=1.9->transformers[torch]) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.12.0,>=1.9->transformers[torch]) (16.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.12.0,>=1.9->transformers[torch]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.9->transformers[torch]) (1.3.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.21.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.16.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4)
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# **4. Import Libraries and Load Model**
#
# We're importing the necessary functions and classes from the installed libraries. Then we check if a GPU is available for training, and load the GPT-2 tokenizer and model.

# %%
import torch, os, re, pandas as pd, json
from sklearn.model_selection import train_test_split
from transformers import DataCollatorForLanguageModeling, DataCollatorWithPadding, GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments, AutoConfig
from datasets import Dataset
from transformers import TextDataset, DataCollatorForLanguageModeling
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from transformers import Trainer, TrainingArguments

# %%
# Load the tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# %%
if torch.cuda.is_available():
    dev = "cuda:0"
else:
    dev = "cpu"
device = torch.device(dev)

# %% [markdown]
# **5. Define Special Tokens and Modify the Tokenizer and Model**
#
# We're defining new special tokens (bos - beginning of string, eos - end of string, and pad - padding) and adding them to our tokenizer. The pre-trained model is then loaded with a custom configuration to accommodate these new tokens, and the model's embeddings are resized accordingly.

# %%
# the eos and bos tokens are defined
bos = '<|endoftext|>'
eos = '<|EOS|>'
pad = '<|pad|>'

special_tokens_dict = {'eos_token': eos, 'bos_token': bos, 'pad_token': pad}

# the new token is added to the tokenizer
num_added_toks = tokenizer.add_special_tokens(special_tokens_dict)

# the model config to which we add the special tokens
config = AutoConfig.from_pretrained('gpt2',
                                    bos_token_id=tokenizer.bos_token_id,
                                    eos_token_id=tokenizer.eos_token_id,
                                    pad_token_id=tokenizer.pad_token_id,
                                    output_hidden_states=False)

# the pre-trained model is loaded with the custom configuration
base_model = GPT2LMHeadModel.from_pretrained('gpt2', config=config)

# the model embedding is resized
base_model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(50259, 768)

# %% [markdown]
# **6. Prepare the Data**
#
# We're creating a pandas dataframe from our lines of text and add special tokens to each line. Then, we're splitting the data into a training set and a validation set. Each set is then converted to a Hugging Face dataset.

# %%
#from transformers import AdamW, AutoTokenizer, AutoModelForSequenceClassification,DataCollatorWithPadding
# Tokenize the text data and convert it to tensors
#lines
df=pd.DataFrame(lines,columns=["texts"])
df["texts"]=bos+df["texts"]+eos
df_train,df_val=train_test_split(df,test_size=0.1,random_state=42)
#input_ids = [tokenizer.encode(line, return_tensors="pt",padding=True) for line in lines]

# %%
df_train.reset_index(inplace=True)
df_train.drop(["index"],axis=1,inplace=True)
df_train
# Out:
#                                                   texts
# 0     <|endoftext|>Components that can be isolated a...
# 1     <|endoftext|>The safe -life for pressure vesse...
# 2     <|endoftext|>Vent outlets shall be protected a...
# 3     <|endoftext|>The flaw detection capability sha...
# 4     <|endoftext|>The Range User  responsible for t...
# ...                                                 ...
# 2164  <|endoftext|>Manual or remote valve actuators ...
# 2165  <|endoftext|>In  addition, procurement require...
# 2166  <|endoftext|>Every pressure vessel and pressur...
# 2167  <|endoftext|>After the pressure cycle testing,...
# 2168  <|endoftext|>3, including pressure  gauges, tr...
#
# [2169 rows x 1 columns]

# %%
df_val.reset_index(inplace=True)
df_val.drop(["index"],axis=1,inplace=True)
df_val
# Out:
#                                                  texts
# 0    <|endoftext|>All ETS interconnections shall pr...
# 1    <|endoftext|>Batteries/cells shall be evaluate...
# 2    <|endoftext|>A material compatib ility analysi...
# 3    <|endoftext|>Loads combinations shall be in ac...
# 4    <|endoftext|>9 and shall be constructed  of wr...
# ..                                                 ...
# 236  <|endoftext|>For non - metallic lined COPVs, t...
# 237  <|endoftext|>Cryogenic vessels and tanks  shal...
# 238  <|endoftext|>EMFR power at the EED shall not e...
# 239  <|endoftext|>Lift trucks shall be in accordanc...
# 240  <|endoftext|>These readings shall be taken bef...
#
# [241 rows x 1 columns]

# %%
train_dataset=Dataset.from_pandas(df_train[["texts"]])
train_dataset
#df_val#.drop(["index"],axis=1,inplace=True)
#val_dataset=Dataset.from_pandas(df_val)
#val_dataset
# Out:
# Dataset({
#     features: ['texts'],
#     num_rows: 2169
# })

# %%
val_dataset=Dataset.from_pandas(df_val[["texts"]])
val_dataset
# Out:
# Dataset({
#     features: ['texts'],
#     num_rows: 241
# })

# %% [markdown]
# **7. Tokenize the Datasets**
#
# A function to tokenize the datasets is defined, and then applied to both the training and validation datasets. This will prepare the datasets for input into our model.

# %%
def tokenize_function(examples,base_tokenizer=tokenizer):
        return base_tokenizer(examples['texts'], padding=True)

tokenized_train_dataset = train_dataset.map(
    tokenize_function,
    batched=True,
    num_proc=5,
    remove_columns=['texts'],
)
tokenized_val_dataset = val_dataset.map(
    tokenize_function,
    batched=True,
    num_proc=5,
    remove_columns=['texts'],
)
# Out:
# Map (num_proc=5):   0%|          | 0/2169 [00:00<?, ? examples/s]
# Map (num_proc=5):   0%|          | 0/241 [00:00<?, ? examples/s]

# %%
tokenizer.decode(tokenized_train_dataset['input_ids'][1])
# Out:
# '<|endoftext|>The safe -life for pressure vessels and pressurized structures shall be established  assuming the existence of pre -existing initial flaws or cracks in the vessel and shall cover  the maximum expected operating loads and environments. <|EOS|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|> <|pad|>'

# %% [markdown]
# **8. Set Up the Data Collator and Training Arguments, Initialize the Trainer and Start Training**
#
# The data collator is responsible for collating multiple data samples into a batch. We're also defining the arguments for training, such as the number of epochs, batch size, and learning rate schedule.
#
# We're initializing the Trainer class with our model, training arguments, and datasets, and then begin training the model.

# %%
data_collator = DataCollatorForLanguageModeling(
        tokenizer=tokenizer,
        mlm=False
    )
output_dir = "requirement_generator"
training_args = TrainingArguments(
    output_dir=output_dir,          # output directory
    num_train_epochs=12,              # total # of training epochs
    per_device_train_batch_size=32,  # batch size per device during training"
    per_device_eval_batch_size=16,   # batch size for evaluation
    warmup_steps=200,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    prediction_loss_only=True,
    save_steps=1000 ,
    logging_dir='requirement_generator',            # directory for storing logs
    push_to_hub=True,
    push_to_hub_model_id="GPT2_Fine_Tune_Requirement_Produce"
)

trainer = Trainer(
    model=base_model,                         # the instantiated  Transformers model to be trained                # training arguments, defined above
    args=training_args,                  # training arguments, defined above
    data_collator=data_collator,
    train_dataset=tokenized_train_dataset,         # training dataset
    eval_dataset=tokenized_val_dataset            # evaluation dataset
)
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1592: FutureWarning: `--push_to_hub_model_id` is deprecated and will be removed in version 5 of 🤗 Transformers. Use `--hub_model_id` instead and pass the full repo name to this argument (in this case AliChazz/GPT2_Fine_Tune_Requirement_Produce).
#   warnings.warn(
# Cloning https://huggingface.co/AliChazz/GPT2_Fine_Tune_Requirement_Produce into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/AliChazz/GPT2_Fine_Tune_Requirement_Produce into local empty directory.
# Download file pytorch_model.bin:   0%|          | 1.41k/487M [00:00<?, ?B/s]
# Download file 1678696199.8553681/events.out.tfevents.1678696199.30e4f66cb7ee.411.1: 100%|##########| 5.58k/5.5…
# Download file events.out.tfevents.1678697139.30e4f66cb7ee.411.2: 100%|##########| 4.53k/4.53k [00:00<?, ?B/s]
# Download file events.out.tfevents.1678696199.30e4f66cb7ee.411.0: 100%|##########| 4.53k/4.53k [00:00<?, ?B/s]
# Download file 1678697139.04395/events.out.tfevents.1678697139.30e4f66cb7ee.411.3: 100%|##########| 5.58k/5.58k…
# Clean file 1678696199.8553681/events.out.tfevents.1678696199.30e4f66cb7ee.411.1:  18%|#7        | 1.00k/5.58k …
# Clean file events.out.tfevents.1678697139.30e4f66cb7ee.411.2:  22%|##2       | 1.00k/4.53k [00:00<?, ?B/s]
# Clean file events.out.tfevents.1678696199.30e4f66cb7ee.411.0:  22%|##2       | 1.00k/4.53k [00:00<?, ?B/s]
# Clean file 1678697139.04395/events.out.tfevents.1678697139.30e4f66cb7ee.411.3:  18%|#7        | 1.00k/5.58k [0…
# Download file training_args.bin: 100%|##########| 3.43k/3.43k [00:00<?, ?B/s]
# Clean file training_args.bin:  29%|##9       | 1.00k/3.43k [00:00<?, ?B/s]
# Clean file pytorch_model.bin:   0%|          | 1.00k/487M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='816' max='816' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [816/816 15:46, Epoch 12/12]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>8.303800</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=816, training_loss=6.076914768592984, metrics={'train_runtime': 951.611, 'train_samples_per_second': 27.352, 'train_steps_per_second': 0.857, 'total_flos': 1859623557120000.0, 'train_loss': 6.076914768592984, 'epoch': 12.0})

# %% [markdown]
# If desired, the trained model can be pushed to huggingface hub.

# %%
trainer.push_to_hub()
#tokenizer.save_pretrained(output_dir)
#trainer.save_model("requirement_producer")
# Out:
# Saving model checkpoint to requirement_generator
# Configuration saved in requirement_generator/config.json
# Configuration saved in requirement_generator/generation_config.json
# Model weights saved in requirement_generator/pytorch_model.bin
# To https://huggingface.co/AliChazz/GPT2_Fine_Tune_Requirement_Produce
#    d61b80d..39e5e71  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/AliChazz/GPT2_Fine_Tune_Requirement_Produce
#    d61b80d..39e5e71  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Causal Language Modeling', 'type': 'text-generation'}}
# 'https://huggingface.co/AliChazz/GPT2_Fine_Tune_Requirement_Produce/commit/39e5e71ff0e9ef85bb5abe6317d076fdaaacf9a2'

# %% [markdown]
# Now we can generate samples from our model ⚡

# %%
def generate_n_text_samples(model, tokenizer, input_text, device, n_samples = 5):
    text_ids = tokenizer.encode(input_text, return_tensors = 'pt')
    text_ids = text_ids.to(device)
    model = model.to(device)

    generated_text_samples = model.generate(
        text_ids,
        max_length= 100,
        num_return_sequences= n_samples,
        no_repeat_ngram_size= 2,
        repetition_penalty= 1.5,
        top_p= 0.92,
        temperature= .85,
        do_sample= True,
        top_k= 125,
        early_stopping= True
    )
    gen_text = []
    for t in generated_text_samples:
        text = tokenizer.decode(t, skip_special_tokens=True)
        gen_text.append(text)

    return gen_text

# %%
# trained model loading
output_dir = "requirement_generator"
model_headlines_path = "requirement_generator"


headlines_model = GPT2LMHeadModel.from_pretrained(model_headlines_path)
headlines_tokenizer = GPT2Tokenizer.from_pretrained(model_headlines_path)

device = "cuda:0"

input_text = headlines_tokenizer.bos_token+ "Propulsion System"

# %%
headlines = generate_n_text_samples(headlines_model, headlines_tokenizer,
                                    input_text, device, n_samples = 100)
for h in headlines:
    print(h)
    print()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1259: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# Propulsion System design shall use leak tests to ensure that no  failure of the system fluids can create a hazard.
#
# Propulsion System Components shall be certified IAW the requirements of NFPA 70, Article  501 and use a corrosion detection system.
#
# Propulsion System Components shall demonstrate that the test  parameter(s) is less than 1/10 of full rated load and pressure.
#
# Propulsion System Components shall be leak tested.
#
# Propulsion System Requirements  shall be reviewed and approved by Range Safety.
#
# Propulsion System Components, PSCs, and SSPPs shall be listed by the appropriate  classification authority.
#
# Propulsion System Components and UG -134 components shall be  designed with an acceptance test expected of 5.
#
# Propulsion System Components and Support Equipment for the  Launch Pad or Spacecraft that is normally tethered to a hypergolic propellant system shall be designed, fabricated using commonly applicable launch -related engineering concepts such as cryogenic fuel cell e nstruction (CCE), oxidizer tube fragmentation externa tion of outer envelope gas oxygen cycle by hydrogen peroxide reductase/pneumatics environmen t pressure reducing chemical degradat ion based on proximity during prelaunch processing;
#
# Propulsion System Design and Test  Approval Requirements shall be submitte d IAW Attachment 3, A2.
#
# Propulsion System Requirements for Vehicles  and Launch Pad Systems shall be included in this volume.
#
# Propulsion System Components, Screws and Systems shall  be designed with a minimum of two strikes at the terminals or pillar to prevent sliding t he axis from rotating seats back in line wi th seat’ position.
#
# Propulsion System Components shall include one or more electrically actuated actuators,  capable of being manually operated and monitored.
#
# Propulsion System Components, Systems Engineering and  Design shall have developed test plans to meet the requirements of paragraph 49.
#
# Propulsion System design data shall be submitted IAW  Attachment ‘ A2.
#
# Propulsion System -controlled valves shall have positive stops at each  extreme position to preclude inadvertent thrust ing.
#
# Propulsion System Components and SFP welds shall  be tested to verify fracture resistance meets the acceptance test requirements in 29 CFR 1910.
#
# Propulsion System Components, SFP components  and associated documentation shall be submitted IAW Attachment 3 A2.
#
# Propulsion System Components shall identify the  required components and assembly, as applicable.
#
# Propulsion System S&As shall incorporate a functional safety feature that will preclude  inadvertent component removal, but not the explosive or shorting.
#
# Propulsion System Components shall be designed to a factor of safety  less than 2.
#
# Propulsion System Components, SSCMAN91 -710V3  27 DECEMBER 2022, as applicable: (See also AFI 40.
#
# Propulsion System Components, SSCMAN91 -710V3  27 DECEMBER 2022 [acoustical hazard mitigation] 3.
#
# Propulsion System Components  shall have the capability of connecting to a single lithium battery.
#
# Propulsion System Design -Materials  and Installa tion Requirements for the Installation of Pressure Vessels shall be followed.
#
# Propulsion System Components, SSCMAN91 -710V3  27 DECEMBER 2022 LOS ANGELES COPY, or any combination thereof shall be test positive for helium.
#
# Propulsion System Requirements for the Launch Pad and Spacecraft  shall be in accordance with ASME Boiler -Test Range Ordnance Rules, Section VIII – Pressure Vessels.
#
# Propulsion System Design (PSC) data requirements shall be submitted IAW Attachment  2, A2.
#
# Propulsion System design data shall be submitted IAW Attachment  2, A2.
#
# Propulsion System Components, LIDs and  Pressure Vessels shall be designed to withstand pressures of up (dead center) for a period that is at least 45 minutes.
#
# Propulsion System Components, MSPPs and SFPs shall meet the requirements of  Chapter 6.
#
# Propulsion System Components shall comply with MIL -STD-882G, FTS – Installat ion.
#
# Propulsion System Components  and Supplies shall comply with NFPA 70, Article 501.
#
# Propulsion System Components, SFP components, and LIDs  shall have all the structural characteristics defined in Chapter 6.
#
# Propulsion System Components  shall be designed to withstand repeated cycling from arm or safe for at least 1,000 cycles without any malfunction.
#
# Propulsion System, hydraulic system and/or pressurized storage tanks shall be  designed to provide for a safe working environment.
#
# Propulsion System Requirements for Construction of  Explosive Systems, and the Space Launch Delta Supplements Control Board Requirement, shall be submitted IAW Attachment 6A.
#
# Propulsion System Components, Tubing and Screws  shall be designed to withstand repeated cycling from arm -to-arm with no drain or rewind capability.
#
# Propulsion System Components,  Installa tion and Configuration Data (ISCE), such as launch vehicle envelope design data or NDE plan submitted to Range Safety for review/ approval, shall be used in conjunction with IAW the SRR -approved Space Launch Delta Supplements National Defense Standard User Requirement For Attachment 3.
#
# Propulsion System Components (SPC) and Launch Vehicles  shall be jointly inspected for cracks, flaws or other structural damage before certification.
#
# Propulsion System Components, SSCMAN91 -710V3  27 DECEMBER 2022 [end] Contact with Metallic Materials shall be limited by the design and accept/reject criteria described in AFI 40 – List of Electromagnetic Subsystems, or ASME B30.
#
# Propulsion System Requirements  shall be approved by Range Safety.
#
# Propulsion System, transducers and propellant systems shall be designed with a yield factor of safety not less than  2.
#
# Propulsion System Components shall be designed to have the capability of safely unloading or  removing propellant.
#
# Propulsion System and Launch Control shall approve the launch vehicle, reusable hoses used  for payloads only.
#
# Propulsion System Components, including valves and regulators  shall have safety positive indicators such as “SAFETY” or safe -life indicator.
#
# Propulsion System Combustion Tanks shall be designed  to withstand pressures upto 1.
#
# Propulsion System and subsystems shall be designed to withstand repeated cycling  from the arm position, starting with a low point load of propellants at 150% or higher for 1.
#
# Propulsion System Components shall meet the requirements of paragraph  12.
#
# Propulsion System Design (PSD) Requirements  shall be submitted IAW Attachment 2, A2.
#
# Propulsion System Components shall have the capability of loading and/or unloading SSCMAN91 -710V3  27 DECEMBER 2022 [ 49 U.S. L 341, 650 et al] on a system ASME B31 or equivalent if required; for those relying solely upon lift trucks to load material from an EED tank (festooned with reusable EBW) during prelaunch operations is also s ubmitted in this volume unless otherwise agreed per NASA ‘MSA�
#
# Propulsion System Components shall have a structural adequacy analysis (as defined in ASME Boiler and Pressure Vessel Code, Section VIIIA) or  equivalent quantitative approach to the design of all systems at system MOP before first operational use.
#
# Propulsion System Components, SSPPs and Test Procedures shall  be reviewed to determine the adequacy of external loads for their intended test configuration.
#
# Propulsion System Components shall be leak tested at their ultimate design  limits to ensure that the system does not experience any ignitable fluids during prelaunch operations.
#
# Propulsion System Components shall be designed so that no inadvertent transfer  of components from one system to the safe position will create a hazard.
#
# Propulsion System components such as valves, regulators and  switches shall be designed to a yield factor of safety not less than 3 based on rated loads.
#
# Propulsion System, including controls  and gauges shall be designed to ensure no single fault can cause catastrophic failure in the event of a leak or rupture.
#
# Propulsion System -compatible fluids shall be avoided in  propellant systems.
#
# Propulsion System Components,  NDEs and LIDs shall be reviewed by a Range Safety approved Environmental Protection Agency (EPA) certified Institute of Electrical or Electronics Engineers Laboratory -Radio frequency Radiation Analysis Center accredited IAW the MRNT/RFI program, ASME B31.
#
# Propulsion System Components, Installation and Test Requi rements  shall be reviewed by Range Safety to determine the appropriate system requirements.
#
# Propulsion System Components, SSPPs and Methodologies  for Launch, Departmen t of Space or any other programsmable to Range Safety shall comply with ASME B30.
#
# Propulsion System Components shall have no intervening stop valves  that could create a hazard in the event of valve failure.
#
# Propulsion System Components and S&As shall have structural integrity tests performed  by a qualified radiographic technologist.
#
# Propulsion System Design Data  shall be incorporated into the MSPSP.
#
# Propulsion System Requirements  for Vessels and Launch Vehicles that Connected Associated Users shall be submitted IAW Attachment 3, A2.
#
# Propulsion System Components, e.
#
# Propulsion System Components  and SSCMAN91 -710V3, Continuous Pressure Vessel Systems, for vessels having leak tests required shall also show that the test vessel IAW paragraph (a) of this volume applies to all systems.
#
# Propulsion System Components shall comply with NEC Article 501,  Standard Test Charge for Launch Vehicles and Spacecraft.
#
# Propulsion System Requirements for Vehicles and Launch  Operations shall be submitted IAW Attachment 2, A2.
#
# Propulsion System Design/Operating Rules shall  contain requirements for solid rocket motors and payloads to ensure the proper test method is used.
#
# Propulsion System Components shall be designed to a nd include safety  controls.
#
# Propulsion System Components shall incorporate safety features to minimize  destabilizing shock loads and avoid inadvertent thrust generation.
#
# Propulsion System Combustion Tanks (PSC) shall not be used for high pressure  systems unless specifically approved by Range Safety.
#
# Propulsion System S&As shall be designed so that the motor is  capable of without passing through a single solid metal shell, or it can safely and easily transition to an electrical full power mode with just one arm.
#
# Propulsion System Components shall be designed to operate at a pressure not less than  1.
#
# Propulsion System design shall include ignition circuit, inhibit power switch and  source control panel.
#
# Propulsion System components shall be designed to ensure the minimum arm  pressure in accordance with ASME Boiler and Pressure Vessel Code, Section VIIIG -1.
#
# Propulsion System Components, Tanks and SSCMAN91 -710V3  27 DECEMBER 2022 VENARIO n AIR Force Space Launch Delta Supplements/Instructions shall be submitted IAW Attachment 2.
#
# Propulsion System Components shall be designed so that all cryogenic  components have no contact with adjacent, unprotected parts.
#
# Propulsion System Design (PSD) data requirements shall  be submitted IAW Attachment 2, A2.
#
# Propulsion System Components and User Interlocks shall be designed to prevent  inadvertent component removal, transmission failure or leakage.
#
# Propulsion System Components (PSC) shall be designed to have a safety factor of 4 on specified  system failures mode, with no tolerance level at all.
#
# Propulsion System Components, ETS or RF components  shall not initiate and will perform to specification in the expected operating environments under any set of conditions.
#
# Propulsion System and Launch Control systems shall be designed to ensure that personnel are not exposed  for hazardous operations.
#
# Propulsion System actuators shall have positive electrical leads  to the safe position.
#
# Propulsion System Components, SFP components and associated data shall be  referenced in the MSPSP.
#
# Propulsion System Requirements  shall be summarized in Table 13.
#
# Propulsion System Components and S&As  shall be designed to ensure that the appropriate propellants are accessible for operation.
#
# Propulsion System design shall ensure that personnel are not exposed to  hazardous temperatures or radiation levels during transportation and on deck operations.
#
# Propulsion System Design (PSD) shall meet the requirements of paragraph  12.
#
# Propulsion System Design Criteria for the Launch  Pad shall be used in conjunction with a safe -life analysis to determine that cryogenic systems, propellants and environments will sustain flightworthy h ores during their intended life periods.
#
# Propulsion System design data shall be submitted IAW Attachment  2, A2.
#
# Propulsion System Components  shall be designed to include an ini tial failure mode if the system cannot power up after a short period of operation.
#
# Propulsion System, EFI and RPF components shall meet the  requirements of paragraph 497.
#
# Propulsion System Requirements  shall be designed to provide for the ultimate in control over propellant flow.
#
# Propulsion System and Range User design data shall be  submitted IAW Attachment ‘ A2.
#
# Propulsion System Components shall be designed to ensure that components and support structures  cannot inadvertently induce thrust effects in the system through inadvertent or destabilizing deformation (or burst) of hydraulic fluid.
#
# Propulsion System Components and U struction shall be designed to provide for a smooth launch.
#
# Propulsion System Components, SSCMAN91 -710V3  27 DECEMBER 2022 Valves shall be designed and tested in accordance with ASME B30.
#
# Propulsion System Components shall be designed to provide the required  thrust, pressure and acceleration for flight in accordance with NASA -STD-6006G or equivalent.
#
# Propulsion System Components, Systems, and Devices  shall be evaluated on a case -by-case basis by Range Safety.

# %%
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 241
#   Batch size = 16
#     <div>
#
#       <progress value='16' max='16' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [16/16 00:01]
#     </div>
# {'eval_loss': 3.153956174850464,
#  'eval_runtime': 1.5999,
#  'eval_samples_per_second': 150.635,
#  'eval_steps_per_second': 10.001,
#  'epoch': 12.0}

# %%
base_model.num_parameters
